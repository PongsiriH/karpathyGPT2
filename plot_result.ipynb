# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = ''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

path = 'logging'
log_train = os.path.join(path, 'log_train.txt')
log_val = os.path.join(path, 'log_val.txt')
df_train = pd.read_csv(log_train, names=['step', 'loss', 'lr', 'norm', 'dt', 'tokens/second'])
df_val = pd.read_csv(log_val, names=['step', 'loss', 'lr', 'norm', 'dt', 'tokens/second'])
print(len(df_train))
df_train[-10:]
# Out:
# 954
#      step      loss       lr      norm        dt  tokens/second
# 944   944  3.510972  0.00003  0.205144  2.922266  179411.427053
# 945   945  3.493164  0.00003  0.217975  2.920568  179515.766081
# 946   946  3.555546  0.00003  0.192944  2.920078  179545.871775
# 947   947  3.600661  0.00003  0.212524  2.920884  179496.365425
# 948   948  3.495558  0.00003  0.220772  2.918915  179617.424287
# 949   949  3.507833  0.00003  0.215097  2.921185  179477.818568
# 950   950  3.463792  0.00003  0.212779  2.918324  179653.801680
# 951   951  3.448203  0.00003  0.210543  2.920511  179519.283265
# 952   952  3.360746  0.00003  0.204375  2.922468  179399.073755
# 953   953  3.469945  0.00003  0.203279  3.512086  149281.065886

# %%
adjusted_val_loss = df_val['loss'] * -np.log(1/50257) / df_val['loss'][0]

plt.figure(figsize=(8, 4))
plt.plot(df_train['step'][-200:], df_train['loss'][-200::], c='b', label='val loss')
# plt.scatter(df_val['step'], adjusted_val_loss, c='r', label='train loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.plot(df_train['step'], df_train['norm'], label='gradient norm')
plt.legend()
plt.show()
